-- %%
SELECT
    ProductID,
    SUM(UnitPriceDiscount) AS RemiseTotale
FROM SalesOrderDetail
GROUP BY ProductID;


SELECT
    ProductID,
    SUM(UnitPriceDiscount) AS RemiseTotale
FROM SalesOrderDetail
GROUP BY ProductID
ORDER BY RemiseTotale DESC
LIMIT 1;
